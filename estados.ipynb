# %%
import geopandas as gpd

# %%
estados_gdf = gpd.read_file('./frontend/src/data/estados.json')

# %%
estados_unicos = estados_gdf.groupby(['id_estado','estado']).size().reset_index(name='count')
estados_unicos.head(40)
# Out:
#     id_estado                           estado  count
# 0           1                   aguascalientes      1
# 1           2                  baja california     76
# 2           3              baja california sur    170
# 3           4                         campeche     84
# 4           5             coahuila de zaragoza      1
# 5           6                           colima      5
# 6           7                          chiapas     26
# 7           8                        chihuahua      1
# 8           9                 distrito federal      1
# 9          10                          durango      1
# 10         11                       guanajuato      1
# 11         12                         guerrero     21
# 12         13                          hidalgo      1
# 13         14                          jalisco     23
# 14         15                           mexico      1
# 15         16              michoacan de ocampo      3
# ...
